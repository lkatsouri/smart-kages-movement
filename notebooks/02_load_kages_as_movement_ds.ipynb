# %% [markdown]
# # Load data from Smart-Kages into `movement` datasets
# Load all DLC .h5 pose files for each kage and concatenate them
# into a single `movement` dataset.
#
# Assign a datetime index across the `time` dimension for easy access.
#
# Save the resulting dataset to a netCDF file.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import seaborn as sns
import xarray as xr
from matplotlib import pyplot as plt
from movement.io import load_poses

from smart_kages_movement.io import load_background_frame

# %% [markdown]
# ## Configuration
# Define some global variables and paths.

# %%
FPS = 2  # frames per second
PIXELS_PER_CM = 10  # pixels per centimetre (need to double-check this)
TIME_PRECISION = "ns"

# Configure seaborn for prettier plots
sns.set_context("notebook")
sns.set_style("ticks")

# %%
data_dir = Path.home() / "UCL Dropbox" / "Loukia Katsouri" / "DataProtocolsEquipment" / "SmartKages" /"1.Analysis_DS_Apr-May2024" / "RawData_300525"
analysis_dir = data_dir / "movement_analysis"
# csv file generated by the 01 notebook
df_path = analysis_dir / "all_segments.csv"
overlaps_path = analysis_dir / "segment_overlaps.csv"


for path in [data_dir, analysis_dir, df_path, overlaps_path]:
    if not path.exists():
        print(f"Path does not exist: {path}")

# %% [markdown]
# ## Load CSV files as datframes

# %% [markdown]
# We load the dataframe containing the paths to all the DLC .h5 files, which is generated in the 01 notebook.

# %%
df = pd.read_csv(
    df_path,
    index_col=[0, 1, 2],
    dtype={
        "date": str,
        "hour": str,
        "n_frames": int,
    },
    parse_dates=["start_datetime", "end_datetime"],
)
df.head()
# Out:
#                          start_datetime            end_datetime  \
# kage  date     hour
# kage1 20240403 09   2024-04-03 09:54:24 2024-04-03 09:59:56.500
#                10   2024-04-03 10:00:06 2024-04-03 10:59:57.500
#                11   2024-04-03 11:01:07 2024-04-03 11:59:59.000
#                12   2024-04-03 12:01:08 2024-04-03 12:59:57.500
#                13   2024-04-03 13:01:07 2024-04-03 13:59:56.000
#
#                                    duration  n_frames  n_channels  height  \
# kage  date     hour
# kage1 20240403 09    0 days 00:05:32.500000       665           3     376
#                10    0 days 00:59:51.500000      7183           3     376
#                11           0 days 00:58:52      7064           1     376
#                12    0 days 00:58:49.500000      7059           3     376
#                13           0 days 00:58:49      7058           3     376
#
#                      width                                     pose_file_path  \
# kage  date     hour
# kage1 20240403 09      500  /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                10      500  /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                11      500  /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                12      500  /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                13      500  /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#
#                                                        video_file_path
# kage  date     hour
# kage1 20240403 09    /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                10    /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                11    /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                12    /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...
#                13    /Users/loukia/UCL Dropbox/Loukia Katsouri/Data...

# %% [markdown]
# We see that the dataframe holds various information on each 1-hour segment of the data.
#
# The index is hierarchical, organising the data first by `kage`, then by `date`, and finally by `hour`.
#
# Of special relevance to us here:
# - Paths: `pose_file_path`, `video_file_path`
# - `start_datetime` and `end_datetime` for each segment
#
# Now let's see which segments overlap with each other (these were pre-computed in the 01 notebook).

# %%
overlaps = pd.read_csv(
    overlaps_path,
    index_col=0,
    parse_dates=["end_A", "start_B"],
)
overlaps
# Out:
#                      segment_A                    segment_B  \
# 0  ('kage3', '20240425', '06')  ('kage3', '20240425', '07')
# 1  ('kage3', '20240504', '06')  ('kage3', '20240504', '07')
#
#                     end_A             start_B overlap_duration
# 0 2024-04-25 06:59:52.500 2024-04-25 06:59:21  00:00:31.500000
# 1 2024-05-04 06:59:39.000 2024-05-04 06:59:21         00:00:18

# %% [markdown]
# ## Load all data from a given kage
# We will create a function that, given a kage name, will load all the data from the DLC .h5 files and merge them into a single `movement` dataset.

# %%
def kage_to_movement_ds(
    df: pd.DataFrame,
    kage: str,
    overlaps: pd.DataFrame | None = None,
) -> tuple[xr.Dataset, np.ndarray]:
    """Load all poses for a given kage and return an xarray Dataset.

    Parameters
    ----------
    df : pd.DataFrame
        DataFrame containing the paths to pose files as well as metadata
        for each 1-hour segment.
    kage : str
        The name of the kage to process, e.g., "kage1", "kage2", etc.
    overlaps : pd.DataFrame | None
        Optional, DataFrame containing information about overlapping segments.

    Returns
    -------
    xr.Dataset
        An xarray Dataset containing the poses for the specified kage,
        with time coordinates assigned based on the corrected timestamps.
    np.ndarray
        A background image (numpy array) loaded from the middle segment
        of the kage, used for visualization purposes.

    Notes
    -----
    The returned Dataset will have two time coordinates:
    - ``time``: the primary time coordinate based on the corrected timestamps.
    - ``seconds_since_start``: the secondary time coordinate representing
       seconds elapsed since the start of the kage.
    """

    def _is_monotonic_increasing(arr):
        """Check if a 1D array is monotonically increasing."""
        return (arr[1:] >= arr[:-1]).all()

    print(f"Processing kage: {kage}")
    df_kage = df.loc[kage]
    df_kage = df_kage.sort_index()  # ensure chronological order
    n_days = df_kage.index.get_level_values("date").nunique()
    print(f"Number of days: {n_days}")
    n_segments = df_kage.shape[0]
    print(f"Number of 1-hour segments: {n_segments}")

    kage_start_datetime = pd.Timestamp(
        df_kage["start_datetime"].iloc[0], unit=TIME_PRECISION
    )

    ds_segments = []  # List of xarray Datasets for each 1-hour segment

    for date, hour in df_kage.index:
        # Load the pose data for the current 1-hour segment
        poses = load_poses.from_file(
            df_kage.loc[(date, hour), "pose_file_path"],
            source_software="DeepLabCut",
            fps=FPS,
        )

        # Assert that length of tracks matches the number of video frames
        n_frames = df_kage.loc[(date, hour), "n_frames"]
        assert poses.sizes["time"] == n_frames, (
            f"Number of tracked timepoints ({poses.sizes['time']}) does not "
            f"match the number of frames ({n_frames}) for {date} at {hour}!"
        )

        # Create timestamps starting from the segment start datetime
        # at the specified FPS
        segment_start_datetime = pd.Timestamp(
            df_kage.loc[(date, hour), "start_datetime"], unit=TIME_PRECISION
        )
        timestamps = pd.date_range(
            start=segment_start_datetime,
            periods=n_frames,
            freq=pd.Timedelta(seconds=1 / FPS),
            unit=TIME_PRECISION,
        )

        # Sanity check: final timestamp not differ by more than 1 frame
        # from the segment end datetime
        segment_end_datetime = pd.Timestamp(
            df_kage.loc[(date, hour), "end_datetime"], unit=TIME_PRECISION
        )
        tolerance = pd.Timedelta(1 / FPS, "sec")
        assert timestamps[-1] - segment_end_datetime <= tolerance, (
            f"Final timestamp {timestamps[-1]} differs by more than "
            f"{tolerance} from segment end datetime {segment_end_datetime}"
        )

        # assign time coordinates to the actual datetime timestamps
        poses = poses.assign_coords(time=timestamps)
        poses.attrs["time_unit"] = f"datetime64[{TIME_PRECISION}]"

        # If this segment overlaps with the next one,
        # we'll delete overlapping frames at the end of this segment
        segment_str = f"('{kage}', '{date}', '{hour}')"
        if (overlaps is not None) and segment_str in overlaps[
            "segment_A"
        ].values:
            row_index = overlaps.index[overlaps["segment_A"] == segment_str][0]
            # Delete everything that comes after the start time of segment B
            next_segment_start = pd.Timestamp(
                overlaps.loc[row_index, "start_B"], unit=TIME_PRECISION
            )
            poses = poses.sel(time=slice(None, next_segment_start - tolerance))
            n_removed = n_frames - poses.sizes["time"]
            print(
                f"Removed {n_removed} overlapping frames at the end of "
                f"segment {date} {hour} for {kage}."
            )

        # add to list of loaded segments
        ds_segments.append(poses)

    # Combine all segments into a single xarray Dataset
    ds_kage = xr.concat(ds_segments, dim="time")
    ds_kage.attrs["kage"] = kage
    ds_kage.attrs["kage_start_datetime"] = kage_start_datetime.isoformat()

    # Ensure the concatenated timestamps are monotonic increasing
    assert _is_monotonic_increasing(ds_kage.time.values), (
        f"Combined timestamps for {kage} are not monotonic increasing!"
    )

    # Assign secondary time coordinate as seconds elapsed since kage start
    seconds_since_kage_start = (
        ds_kage.time.data - np.datetime64(kage_start_datetime)
    ) / pd.Timedelta("1s")
    ds_kage = ds_kage.assign_coords(
        seconds_elapsed=("time", seconds_since_kage_start)
    )

    # load image to use as background frame
    video_path = df_kage.iloc[n_segments // 2]["video_file_path"]
    background_img = load_background_frame(
        video_path=video_path, i=0, n_average=100
    )
    print(f"Loaded background image for {kage} from {video_path} \n")

    return ds_kage, background_img

# %% [markdown]
# Now let's create a combined `movement` dataset for each kage.
#
# We also assign a background image to each kage, which is used for visualisation purposes.

# %%
ds_dict = {}  # List of `movement` datasets for each kage
img_dict = {}  # List of background images for each kage

for kage in df.index.get_level_values("kage").unique():
    ds_dict[kage], img_dict[kage] = kage_to_movement_ds(df, kage, overlaps)
# Out:
# Processing kage: kage1
# Number of days: 35
# Number of 1-hour segments: 760
# Loaded background image for kage1 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage1/videos/2024/04/23/kage1_20240423_130002.mp4
#
# Processing kage: kage10
# Number of days: 38
# Number of 1-hour segments: 859
# Loaded background image for kage10 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage10/videos/2024/04/21/kage10_20240421_010002.mp4
#
# Processing kage: kage11
# Number of days: 38
# Number of 1-hour segments: 866
# Loaded background image for kage11 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage11/videos/2024/04/21/kage11_20240421_040002.mp4
#
# Processing kage: kage12
# Number of days: 38
# Number of 1-hour segments: 854
# Loaded background image for kage12 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage12/videos/2024/04/21/kage12_20240421_040002.mp4
#
# Processing kage: kage13
# Number of days: 38
# Number of 1-hour segments: 893
# Loaded background image for kage13 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage13/videos/2024/04/21/kage13_20240421_170002.mp4
#
# Processing kage: kage14
# Number of days: 33
# Number of 1-hour segments: 754
# Loaded background image for kage14 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage14/videos/2024/04/24/kage14_20240424_110002.mp4
#
# Processing kage: kage15
# Number of days: 27
# Number of 1-hour segments: 611
# Loaded background image for kage15 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage15/videos/2024/04/27/kage15_20240427_140002.mp4
#
# Processing kage: kage16
# Number of days: 38
# Number of 1-hour segments: 888
# Loaded background image for kage16 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage16/videos/2024/04/21/kage16_20240421_160002.mp4
#
# Processing kage: kage17
# Number of days: 38
# Number of 1-hour segments: 894
# Loaded background image for kage17 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage17/videos/2024/04/21/kage17_20240421_170002.mp4
#
# Processing kage: kage18
# Number of days: 39
# Number of 1-hour segments: 886
# Loaded background image for kage18 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage18/videos/2024/04/21/kage18_20240421_160002.mp4
#
# Processing kage: kage19
# Number of days: 30
# Number of 1-hour segments: 697
# Loaded background image for kage19 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage19/videos/2024/04/26/kage19_20240426_020002.mp4
#
# Processing kage: kage2
# Number of days: 38
# Number of 1-hour segments: 896
# Loaded background image for kage2 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage2/videos/2024/04/21/kage2_20240421_160002.mp4
#
# Processing kage: kage20
# Number of days: 30
# Number of 1-hour segments: 698
# Loaded background image for kage20 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage20/videos/2024/04/26/kage20_20240426_020002.mp4
#
# Processing kage: kage21
# Number of days: 30
# Number of 1-hour segments: 534
# Loaded background image for kage21 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage21/videos/2024/04/25/kage21_20240425_090002.mp4
#
# Processing kage: kage22
# Number of days: 30
# Number of 1-hour segments: 699
# Loaded background image for kage22 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage22/videos/2024/04/26/kage22_20240426_010001.mp4
#
# Processing kage: kage23
# Number of days: 30
# Number of 1-hour segments: 698
# Loaded background image for kage23 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage23/videos/2024/04/26/kage23_20240426_020001.mp4
#
# Processing kage: kage24
# Number of days: 30
# Number of 1-hour segments: 699
# Loaded background image for kage24 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage24/videos/2024/04/26/kage24_20240426_010002.mp4
#
# Processing kage: kage25
# Number of days: 30
# Number of 1-hour segments: 698
# Loaded background image for kage25 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage25/videos/2024/04/26/kage25_20240426_010002.mp4
#
# Processing kage: kage26
# Number of days: 26
# Number of 1-hour segments: 604
# Loaded background image for kage26 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage26/videos/2024/04/28/kage26_20240428_010002.mp4
#
# Processing kage: kage27
# Number of days: 31
# Number of 1-hour segments: 722
# Loaded background image for kage27 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage27/videos/2024/04/25/kage27_20240425_140002.mp4
#
# Processing kage: kage28
# Number of days: 30
# Number of 1-hour segments: 560
# Loaded background image for kage28 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage28/videos/2024/04/26/kage28_20240426_030002.mp4
#
# Processing kage: kage29
# Number of days: 30
# Number of 1-hour segments: 695
# Loaded background image for kage29 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage29/videos/2024/04/26/kage29_20240426_000002.mp4
#
# Processing kage: kage3
# Number of days: 39
# Number of 1-hour segments: 855
# Removed 63 overlapping frames at the end of segment 20240425 06 for kage3.
# Removed 36 overlapping frames at the end of segment 20240504 06 for kage3.
# Loaded background image for kage3 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage3/videos/2024/04/21/kage3_20240421_120002.mp4
#
# Processing kage: kage30
# Number of days: 28
# Number of 1-hour segments: 649
# Loaded background image for kage30 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage30/videos/2024/04/25/kage30_20240425_030002.mp4
#
# Processing kage: kage31
# Number of days: 30
# Number of 1-hour segments: 697
# Loaded background image for kage31 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage31/videos/2024/04/26/kage31_20240426_000002.mp4
#
# Processing kage: kage32
# Number of days: 37
# Number of 1-hour segments: 855
# Loaded background image for kage32 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage32/videos/2024/04/22/kage32_20240422_180002.mp4
#
# Processing kage: kage33
# Number of days: 37
# Number of 1-hour segments: 861
# Loaded background image for kage33 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage33/videos/2024/04/22/kage33_20240422_140002.mp4
#
# Processing kage: kage4
# Number of days: 38
# Number of 1-hour segments: 891
# Loaded background image for kage4 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage4/videos/2024/04/21/kage4_20240421_160002.mp4
#
# Processing kage: kage5
# Number of days: 38
# Number of 1-hour segments: 891
# Loaded background image for kage5 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage5/videos/2024/04/21/kage5_20240421_160002.mp4
#
# Processing kage: kage6
# Number of days: 38
# Number of 1-hour segments: 890
# Loaded background image for kage6 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage6/videos/2024/04/21/kage6_20240421_180002.mp4
#
# Processing kage: kage7
# Number of days: 38
# Number of 1-hour segments: 892
# Loaded background image for kage7 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage7/videos/2024/04/21/kage7_20240421_140002.mp4
#
# Processing kage: kage8
# Number of days: 39
# Number of 1-hour segments: 847
# Loaded background image for kage8 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage8/videos/2024/04/20/kage8_20240420_220002.mp4
#
# Processing kage: kage9
# Number of days: 38
# Number of 1-hour segments: 865
# Loaded background image for kage9 from /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/kage9/videos/2024/04/21/kage9_20240421_030001.mp4

# %%
# Inspect the dataset for kage1
ds_dict["kage3"]
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:          (time: 6091917, space: 2, keypoints: 8, individuals: 1)
# Coordinates:
#   * space            (space) <U1 8B 'x' 'y'
#   * keypoints        (keypoints) <U10 320B 'snout' 'leftear' ... 'tailbase'
#   * individuals      (individuals) <U12 48B 'individual_0'
#   * time             (time) datetime64[ns] 49MB 2024-04-02T17:03:26 ... 2024-...
#     seconds_elapsed  (time) float64 49MB 0.0 0.5 1.0 ... 3.254e+06 3.254e+06
# Data variables:
#     position         (time, space, keypoints, individuals) float64 780MB 464....
#     confidence       (time, keypoints, individuals) float64 390MB 0.9944 ... ...
# Attributes:
#     source_software:      DeepLabCut
#     ds_type:              poses
#     fps:                  2.0
#     time_unit:            datetime64[ns]
#     source_file:          /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProto...
#     kage:                 kage3
#     kage_start_datetime:  2024-04-02T17:03:26

# %% [markdown]
# ## Save the combined datasets to netCDF files
# Finally, we save the combined `movement` datasets for each kage to a netCDF file.
#
# We also save the background image for each kage in the same directory.

# %%
for kage, ds in ds_dict.items():
    print(f"Saving dataset for {kage}...")
    kage_dir = analysis_dir / kage
    kage_dir.mkdir(parents=True, exist_ok=True)
    ds_file_path = kage_dir / f"{kage}.nc"
    ds.to_netcdf(ds_file_path, mode="w", engine="netcdf4", format="NETCDF4")
    print(f"Dataset for {kage} saved to {ds_file_path}.")

    img_file_path = kage_dir / f"{kage}_background.png"
    plt.imsave(img_file_path, img_dict[kage])
    print(f"Background image for {kage} saved to {img_file_path}.\n")
# Out:
# Saving dataset for kage1...
# Dataset for kage1 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage1/kage1.nc.
# Background image for kage1 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage1/kage1_background.png.
#
# Saving dataset for kage10...
# Dataset for kage10 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage10/kage10.nc.
# Background image for kage10 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage10/kage10_background.png.
#
# Saving dataset for kage11...
# Dataset for kage11 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage11/kage11.nc.
# Background image for kage11 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage11/kage11_background.png.
#
# Saving dataset for kage12...
# Dataset for kage12 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage12/kage12.nc.
# Background image for kage12 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage12/kage12_background.png.
#
# Saving dataset for kage13...
# Dataset for kage13 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage13/kage13.nc.
# Background image for kage13 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage13/kage13_background.png.
#
# Saving dataset for kage14...
# Dataset for kage14 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage14/kage14.nc.
# Background image for kage14 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage14/kage14_background.png.
#
# Saving dataset for kage15...
# Dataset for kage15 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage15/kage15.nc.
# Background image for kage15 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage15/kage15_background.png.
#
# Saving dataset for kage16...
# Dataset for kage16 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage16/kage16.nc.
# Background image for kage16 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage16/kage16_background.png.
#
# Saving dataset for kage17...
# Dataset for kage17 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage17/kage17.nc.
# Background image for kage17 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage17/kage17_background.png.
#
# Saving dataset for kage18...
# Dataset for kage18 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage18/kage18.nc.
# Background image for kage18 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage18/kage18_background.png.
#
# Saving dataset for kage19...
# Dataset for kage19 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage19/kage19.nc.
# Background image for kage19 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage19/kage19_background.png.
#
# Saving dataset for kage2...
# Dataset for kage2 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage2/kage2.nc.
# Background image for kage2 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage2/kage2_background.png.
#
# Saving dataset for kage20...
# Dataset for kage20 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage20/kage20.nc.
# Background image for kage20 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage20/kage20_background.png.
#
# Saving dataset for kage21...
# Dataset for kage21 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage21/kage21.nc.
# Background image for kage21 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage21/kage21_background.png.
#
# Saving dataset for kage22...
# Dataset for kage22 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage22/kage22.nc.
# Background image for kage22 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage22/kage22_background.png.
#
# Saving dataset for kage23...
# Dataset for kage23 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage23/kage23.nc.
# Background image for kage23 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage23/kage23_background.png.
#
# Saving dataset for kage24...
# Dataset for kage24 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage24/kage24.nc.
# Background image for kage24 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage24/kage24_background.png.
#
# Saving dataset for kage25...
# Dataset for kage25 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage25/kage25.nc.
# Background image for kage25 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage25/kage25_background.png.
#
# Saving dataset for kage26...
# Dataset for kage26 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage26/kage26.nc.
# Background image for kage26 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage26/kage26_background.png.
#
# Saving dataset for kage27...
# Dataset for kage27 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage27/kage27.nc.
# Background image for kage27 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage27/kage27_background.png.
#
# Saving dataset for kage28...
# Dataset for kage28 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage28/kage28.nc.
# Background image for kage28 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage28/kage28_background.png.
#
# Saving dataset for kage29...
# Dataset for kage29 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage29/kage29.nc.
# Background image for kage29 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage29/kage29_background.png.
#
# Saving dataset for kage3...
# Dataset for kage3 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage3/kage3.nc.
# Background image for kage3 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage3/kage3_background.png.
#
# Saving dataset for kage30...
# Dataset for kage30 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage30/kage30.nc.
# Background image for kage30 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage30/kage30_background.png.
#
# Saving dataset for kage31...
# Dataset for kage31 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage31/kage31.nc.
# Background image for kage31 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage31/kage31_background.png.
#
# Saving dataset for kage32...
# Dataset for kage32 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage32/kage32.nc.
# Background image for kage32 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage32/kage32_background.png.
#
# Saving dataset for kage33...
# Dataset for kage33 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage33/kage33.nc.
# Background image for kage33 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage33/kage33_background.png.
#
# Saving dataset for kage4...
# Dataset for kage4 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage4/kage4.nc.
# Background image for kage4 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage4/kage4_background.png.
#
# Saving dataset for kage5...
# Dataset for kage5 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage5/kage5.nc.
# Background image for kage5 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage5/kage5_background.png.
#
# Saving dataset for kage6...
# Dataset for kage6 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage6/kage6.nc.
# Background image for kage6 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage6/kage6_background.png.
#
# Saving dataset for kage7...
# Dataset for kage7 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage7/kage7.nc.
# Background image for kage7 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage7/kage7_background.png.
#
# Saving dataset for kage8...
# Dataset for kage8 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage8/kage8.nc.
# Background image for kage8 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage8/kage8_background.png.
#
# Saving dataset for kage9...
# Dataset for kage9 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage9/kage9.nc.
# Background image for kage9 saved to /Users/loukia/UCL Dropbox/Loukia Katsouri/DataProtocolsEquipment/SmartKages/1.Analysis_DS_Apr-May2024/RawData_300525/movement_analysis/kage9/kage9_background.png.
